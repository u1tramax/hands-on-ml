# %% [markdown]
# **Одновыборочный t-тест:**
# $$t = \frac{\bar{X} - \mu_0}{s / \sqrt{n}}$$
#
# **Двухвыборочный t-тест:**
# $$t = \frac{\bar{X}_1 - \bar{X}_2}{s_p \sqrt{\frac{1}{n_1} + \frac{1}{n_2}}}$$
#
# **Парный t-тест:**
# $$t = \frac{\bar{D}}{s_D / \sqrt{n}}$$

# %%
import numpy as np
import pandas as pd
from math import *
from scipy import stats

# %% [markdown]
# Example 1: Is there a significant difference in test scores between 25 students who received in-person instruction and 25 students who received online instruction? The mean test score for the in-person group is 80 (SD = 5) and for the online group is 75 (SD = 7).

# %%
mean1, mean2 = 80, 75
n1, n2 = 25, 25
std1, std2 = 5, 7
var1, var2 = std1 ** 2, std2 ** 2

t = (mean1 - mean2) / sqrt(var1 / n1 + var2 / n2)
t
# Out:
# 2.906190968595482

# %% [markdown]
# Example 2: A researcher wants to know if there is a significant difference in the weight of newborn babies between two hospitals in a city. The researcher randomly selects 20 newborns from Hospital A and 20 newborns from Hospital B and records their weights in pounds. The mean weight for the Hospital A group is 7.5, with a standard deviation of 0.8. The mean weight for the Hospital B group is 7.1, with a standard deviation of 1.2. Is there a significant difference between the two hospitals?

# %%
mean1, mean2 = 7.5, 7.1
n1, n2 = 20, 20
std1, std2 = 0.8, 1.2
var1, var2 = std1 ** 2, std2 ** 2

t = (mean1 - mean2) / sqrt(var1 / n1 + var2 / n2)
t
# Out:
# 1.2403473458920855
