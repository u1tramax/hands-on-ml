# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
df_categorical = df.select_dtypes(include='object')

# %%
df_categorical
# Out:
#         gender ethnicity education_level  income_level smoking_status  \
# 0       Female  Hispanic      Highschool  Lower-Middle        Current
# 1       Female     White      Highschool  Upper-Middle          Never
# 2         Male  Hispanic      Highschool  Lower-Middle          Never
# 3       Female     White      Highschool  Lower-Middle        Current
# 4         Male     White      Highschool  Upper-Middle          Never
# ...        ...       ...             ...           ...            ...
# 699995  Female  Hispanic    Postgraduate  Upper-Middle         Former
# 699996  Female  Hispanic        Graduate  Upper-Middle         Former
# 699997  Female     White        Graduate        Middle          Never
# 699998  Female     White      Highschool  Lower-Middle          Never
# 699999  Female     Black        Graduate           Low         Former
#
#        employment_status
# 0               Employed
# 1               Employed
# 2                Retired
# ...

# %%
df_categorical['gender'].value_counts()
# Out:
# gender
# Female    363237
# Male      333085
# Other       3678
# Name: count, dtype: int64

# %%
df_categorical['ethnicity'].value_counts()
# Out:
# ethnicity
# White       386153
# Hispanic    129984
# Black       106301
# Asian        60120
# Other        17442
# Name: count, dtype: int64

# %%
df_categorical['education_level'].value_counts()
# Out:
# education_level
# Highschool      344145
# Graduate        261268
# Postgraduate     79642
# No formal        14945
# Name: count, dtype: int64

# %%
df_categorical['income_level'].value_counts()
# Out:
# income_level
# Middle          290557
# Lower-Middle    178570
# Upper-Middle    127836
# Low              85803
# High             17234
# Name: count, dtype: int64

# %%
df_categorical['smoking_status'].value_counts()
# Out:
# smoking_status
# Never      494448
# Current    103363
# Former     102189
# Name: count, dtype: int64

# %%
df_categorical['employment_status'].value_counts()
# Out:
# employment_status
# Employed      516170
# Retired       115735
# Unemployed     49787
# Student        18308
# Name: count, dtype: int64

# %% [markdown]
# Gender and ethnicity can be one-hot encoded, \
# education_level, income_level and smoking status can be oridnal encoded, \
# employment should be one-hot encoded

# %%
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder

# %%
one_hot_categories = [
    'gender', 'ethnicity', 'employment_status'
]
pd.get_dummies(df_categorical[one_hot_categories], dtype=int)
# Out:
#         gender_Female  gender_Male  gender_Other  ethnicity_Asian  \
# 0                   1            0             0                0
# 1                   1            0             0                0
# 2                   0            1             0                0
# 3                   1            0             0                0
# 4                   0            1             0                0
# ...               ...          ...           ...              ...
# 699995              1            0             0                0
# 699996              1            0             0                0
# 699997              1            0             0                0
# 699998              1            0             0                0
# 699999              1            0             0                0
#
#         ethnicity_Black  ethnicity_Hispanic  ethnicity_Other  ethnicity_White  \
# 0                     0                   1                0                0
# ...

# %%
ordinal_categories = [
    ['No formal', 'Highschool', 'Graduate', 'Postgraduate'],
    ['Low', 'Lower-Middle', 'Middle', 'Upper-Middle', 'High'],
    ['Never', 'Former', 'Current']
]
ordinal_encoder = OrdinalEncoder(categories=ordinal_categories)
ordinal_encoder.fit_transform(df[['education_level', 'income_level', 'smoking_status']])
# Out:
# array([[1., 1., 2.],
#        [1., 3., 0.],
#        [1., 1., 0.],
#        ...,
#        [2., 2., 0.],
#        [1., 1., 0.],
#        [2., 0., 1.]])
