# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')
df = df.drop('id', axis=1)

# %%
one_hot_categories = ['gender', 'ethnicity', 'employment_status']
df = pd.concat([df.drop(one_hot_categories, axis=1), pd.get_dummies(df[one_hot_categories], dtype=int)], axis=1)

# %%
from sklearn.preprocessing import OrdinalEncoder

ordinal_categories = ['education_level', 'income_level', 'smoking_status']
ordinal_columns = [
    ['No formal', 'Highschool', 'Graduate', 'Postgraduate'],
    ['Low', 'Lower-Middle', 'Middle', 'Upper-Middle', 'High'],
    ['Never', 'Former', 'Current']
]
ordinal_encoder = OrdinalEncoder(categories=ordinal_columns)
df = pd.concat(
        [
        df.drop(ordinal_categories, axis=1), 
        pd.DataFrame(ordinal_encoder.fit_transform(df[ordinal_categories]), columns=ordinal_categories)
    ], 
axis=1)

# %%
X, y = df.drop('diagnosed_diabetes', axis=1), df['diagnosed_diabetes']

# %%
from sklearn.model_selection import train_test_split, cross_val_score

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle=True, stratify=y)

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score

def objective(trial):
    param = {
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1),
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'gamma': trial.suggest_float('gamma', 0, 5),
    }
    
    # initializing the XGBoost model
    model = XGBClassifier(**param)
    
    score = cross_val_score(model, X_train, y_train, cv=5).mean()   # calculating score using cross-validation
    return score

# %%
import optuna

# Create and run the optimization process with 100 trials
study = optuna.create_study(study_name="example_xgboost_study", direction='maximize') 
study.optimize(objective, n_trials=100, show_progress_bar=True, n_jobs=-1)   

# Retrieve the best parameter values
best_params = study.best_params
print(f"\nBest parameters: {best_params}")
# Out:
# [I 2025-12-11 03:03:01,211] A new study created in memory with name: example_xgboost_study
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-12-11 03:04:43,070] Trial 2 finished with value: 0.6645793650793651 and parameters: {'max_depth': 7, 'learning_rate': 0.010493072492900365, 'n_estimators': 173, 'subsample': 0.7738842149588019, 'colsample_bytree': 0.6539986070124677, 'min_child_weight': 4, 'gamma': 4.092135395569783}. Best is trial 2 with value: 0.6645793650793651.
# [I 2025-12-11 03:05:38,572] Trial 3 finished with value: 0.6816587301587301 and parameters: {'max_depth': 9, 'learning_rate': 0.0387494925001038, 'n_estimators': 222, 'subsample': 0.9915743233067356, 'colsample_bytree': 0.751537684304319, 'min_child_weight': 8, 'gamma': 1.2687532257780059}. Best is trial 3 with value: 0.6816587301587301.
# [I 2025-12-11 03:06:59,801] Trial 1 finished with value: 0.6795968253968254 and parameters: {'max_depth': 4, 'learning_rate': 0.02960079212651546, 'n_estimators': 721, 'subsample': 0.673888078463168, 'colsample_bytree': 0.6173434547684189, 'min_child_weight': 8, 'gamma': 3.0048003683256734}. Best is trial 3 with value: 0.6816587301587301.
# [I 2025-12-11 03:07:05,221] Trial 6 finished with value: 0.6768603174603174 and parameters: {'max_depth': 5, 'learning_rate': 0.01810474478263427, 'n_estimators': 611, 'subsample': 0.9807947320712103, 'colsample_bytree': 0.9597725314592463, 'min_child_weight': 2, 'gamma': 1.8104946460142197}. Best is trial 3 with value: 0.6816587301587301.
# [I 2025-12-11 03:07:12,770] Trial 8 finished with value: 0.6826142857142857 and parameters: {'max_depth': 8, 'learning_rate': 0.09998648727993868, 'n_estimators': 419, 'subsample': 0.898904981084931, 'colsample_bytree': 0.5934731807961919, 'min_child_weight': 9, 'gamma': 3.1669984677704806}. Best is trial 8 with value: 0.6826142857142857.
# [I 2025-12-11 03:07:33,307] Trial 5 finished with value: 0.6828142857142857 and parameters: {'max_depth': 8, 'learning_rate': 0.04620757965713612, 'n_estimators': 908, 'subsample': 0.9964891845348188, 'colsample_bytree': 0.5806963847524218, 'min_child_weight': 8, 'gamma': 2.136043086429602}. Best is trial 5 with value: 0.6828142857142857.
# [I 2025-12-11 03:07:58,071] Trial 0 finished with value: 0.682747619047619 and parameters: {'max_depth': 8, 'learning_rate': 0.03691523268810305, 'n_estimators': 486, 'subsample': 0.7560373959997264, 'colsample_bytree': 0.62059130978088, 'min_child_weight': 9, 'gamma': 1.49707844841937}. Best is trial 5 with value: 0.6828142857142857.
# [I 2025-12-11 03:09:12,395] Trial 10 finished with value: 0.6815936507936508 and parameters: {'max_depth': 6, 'learning_rate': 0.06370635440221295, 'n_estimators': 283, 'subsample': 0.860034148867816, 'colsample_bytree': 0.5910252639954447, 'min_child_weight': 7, 'gamma': 2.83615921495944}. Best is trial 5 with value: 0.6828142857142857.
# [I 2025-12-11 03:10:10,997] Trial 9 finished with value: 0.680926984126984 and parameters: {'max_depth': 9, 'learning_rate': 0.07547329295509837, 'n_estimators': 518, 'subsample': 0.6468430534427545, 'colsample_bytree': 0.9717652081302686, 'min_child_weight': 6, 'gamma': 4.2051486926537605}. Best is trial 5 with value: 0.6828142857142857.
# [I 2025-12-11 03:10:20,522] Trial 15 finished with value: 0.6747904761904763 and parameters: {'max_depth': 3, 'learning_rate': 0.06798489278623655, 'n_estimators': 264, 'subsample': 0.9199271307281836, 'colsample_bytree': 0.842893202697558, 'min_child_weight': 1, 'gamma': 3.41588408517486}. Best is trial 5 with value: 0.6828142857142857.
# [I 2025-12-11 03:10:36,572] Trial 7 finished with value: 0.6766253968253968 and parameters: {'max_depth': 9, 'learning_rate': 0.09959073983914427, 'n_estimators': 747, 'subsample': 0.6080543153745341, 'colsample_bytree': 0.9216543089906242, 'min_child_weight': 5, 'gamma': 2.919501818059285}. Best is trial 5 with value: 0.6828142857142857.
# [I 2025-12-11 03:11:00,481] Trial 13 finished with value: 0.6821396825396826 and parameters: {'max_depth': 8, 'learning_rate': 0.0917331308730915, 'n_estimators': 645, 'subsample': 0.7549227109461201, 'colsample_bytree': 0.9206922185039701, 'min_child_weight': 3, 'gamma': 4.791960084904998}. Best is trial 5 with value: 0.6828142857142857.
# [I 2025-12-11 03:11:24,825] Trial 4 finished with value: 0.6804238095238095 and parameters: {'max_depth': 8, 'learning_rate': 0.08755398007281102, 'n_estimators': 843, 'subsample': 0.6535147867603945, 'colsample_bytree': 0.6576506531918973, 'min_child_weight': 7, 'gamma': 0.9663330970090722}. Best is trial 5 with value: 0.6828142857142857.
# [I 2025-12-11 03:11:47,216] Trial 12 finished with value: 0.6838285714285715 and parameters: {'max_depth': 4, 'learning_rate': 0.09372619434547808, 'n_estimators': 871, 'subsample': 0.7224135103481155, 'colsample_bytree': 0.8874468905919592, 'min_child_weight': 6, 'gamma': 3.1361649806400287}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:13:25,714] Trial 14 finished with value: 0.6826555555555555 and parameters: {'max_depth': 5, 'learning_rate': 0.039620190633858486, 'n_estimators': 845, 'subsample': 0.707817976099312, 'colsample_bytree': 0.9039831996419465, 'min_child_weight': 7, 'gamma': 3.1437729526495306}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:13:59,066] Trial 16 finished with value: 0.6768206349206348 and parameters: {'max_depth': 3, 'learning_rate': 0.026946526740050294, 'n_estimators': 893, 'subsample': 0.9449264388426152, 'colsample_bytree': 0.8089779694461353, 'min_child_weight': 5, 'gamma': 0.879177961708717}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:15:14,346] Trial 11 finished with value: 0.6831158730158731 and parameters: {'max_depth': 8, 'learning_rate': 0.025486634352473544, 'n_estimators': 964, 'subsample': 0.7224086640095384, 'colsample_bytree': 0.691393206585045, 'min_child_weight': 2, 'gamma': 4.116605384561354}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:17:13,045] Trial 22 finished with value: 0.6807761904761904 and parameters: {'max_depth': 3, 'learning_rate': 0.052246124945178885, 'n_estimators': 931, 'subsample': 0.5213906299416793, 'colsample_bytree': 0.5099075768515113, 'min_child_weight': 10, 'gamma': 0.3037456728414516}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:18:41,834] Trial 18 finished with value: 0.683536507936508 and parameters: {'max_depth': 7, 'learning_rate': 0.04475791912642129, 'n_estimators': 949, 'subsample': 0.5025588056774581, 'colsample_bytree': 0.5001803311718125, 'min_child_weight': 10, 'gamma': 0.17293310775269366}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:19:04,810] Trial 21 finished with value: 0.6831603174603175 and parameters: {'max_depth': 6, 'learning_rate': 0.051979906230887205, 'n_estimators': 997, 'subsample': 0.507707547595323, 'colsample_bytree': 0.5229641584973146, 'min_child_weight': 10, 'gamma': 2.1130063400735515}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:19:15,989] Trial 19 finished with value: 0.6832571428571428 and parameters: {'max_depth': 7, 'learning_rate': 0.04582885534313607, 'n_estimators': 978, 'subsample': 0.529716930554826, 'colsample_bytree': 0.5215520464323603, 'min_child_weight': 10, 'gamma': 0.04572685634592766}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:21:35,347] Trial 25 finished with value: 0.6817460317460318 and parameters: {'max_depth': 10, 'learning_rate': 0.0802797938061545, 'n_estimators': 989, 'subsample': 0.8240453082603537, 'colsample_bytree': 0.7248839641256717, 'min_child_weight': 3, 'gamma': 3.9242656858481286}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:21:57,965] Trial 17 finished with value: 0.6781365079365079 and parameters: {'max_depth': 10, 'learning_rate': 0.050607036135845204, 'n_estimators': 969, 'subsample': 0.5314894672501516, 'colsample_bytree': 0.7290129191461695, 'min_child_weight': 4, 'gamma': 0.04293618673619992}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:22:39,749] Trial 20 finished with value: 0.6807253968253969 and parameters: {'max_depth': 10, 'learning_rate': 0.047365712311097194, 'n_estimators': 951, 'subsample': 0.5117584595692771, 'colsample_bytree': 0.511583816610484, 'min_child_weight': 10, 'gamma': 0.1269635754720111}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:23:48,670] Trial 27 finished with value: 0.6833714285714285 and parameters: {'max_depth': 5, 'learning_rate': 0.0766273026195329, 'n_estimators': 758, 'subsample': 0.5748609058149181, 'colsample_bytree': 0.7436495661034177, 'min_child_weight': 4, 'gamma': 0.38654265640436336}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:24:22,213] Trial 26 finished with value: 0.683415873015873 and parameters: {'max_depth': 6, 'learning_rate': 0.05908657102869308, 'n_estimators': 763, 'subsample': 0.5222186517565387, 'colsample_bytree': 0.5014773538256667, 'min_child_weight': 10, 'gamma': 0.08630497745908583}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:25:00,107] Trial 23 finished with value: 0.6808031746031746 and parameters: {'max_depth': 10, 'learning_rate': 0.050362770529348413, 'n_estimators': 943, 'subsample': 0.5525493873682882, 'colsample_bytree': 0.5032963634277402, 'min_child_weight': 10, 'gamma': 2.1111435276600305}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:25:25,585] Trial 28 finished with value: 0.6830079365079365 and parameters: {'max_depth': 7, 'learning_rate': 0.061810960466951746, 'n_estimators': 707, 'subsample': 0.557119903663672, 'colsample_bytree': 0.5525859420482618, 'min_child_weight': 10, 'gamma': 0.01182643599145889}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:27:11,782] Trial 24 finished with value: 0.6787238095238095 and parameters: {'max_depth': 10, 'learning_rate': 0.051384089696570816, 'n_estimators': 984, 'subsample': 0.5229653008540409, 'colsample_bytree': 0.5189328764407976, 'min_child_weight': 3, 'gamma': 0.1406305386133262}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:28:28,266] Trial 29 finished with value: 0.6829301587301588 and parameters: {'max_depth': 7, 'learning_rate': 0.060057996713465324, 'n_estimators': 787, 'subsample': 0.569511356622507, 'colsample_bytree': 0.5507117221294493, 'min_child_weight': 10, 'gamma': 0.0023614903505769502}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:28:36,577] Trial 30 finished with value: 0.683368253968254 and parameters: {'max_depth': 7, 'learning_rate': 0.06078358474877444, 'n_estimators': 760, 'subsample': 0.5655119564739625, 'colsample_bytree': 0.5527652901337909, 'min_child_weight': 10, 'gamma': 0.5721109931397319}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:28:51,326] Trial 33 finished with value: 0.6826365079365079 and parameters: {'max_depth': 4, 'learning_rate': 0.06091317908502765, 'n_estimators': 823, 'subsample': 0.5904327190761246, 'colsample_bytree': 0.8162854929632155, 'min_child_weight': 9, 'gamma': 0.7912470013737707}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:28:55,006] Trial 32 finished with value: 0.6831333333333334 and parameters: {'max_depth': 5, 'learning_rate': 0.06177820991821022, 'n_estimators': 767, 'subsample': 0.5848355593442217, 'colsample_bytree': 0.8074352095581626, 'min_child_weight': 6, 'gamma': 0.6093293612192753}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:29:19,339] Trial 34 finished with value: 0.6827730158730159 and parameters: {'max_depth': 4, 'learning_rate': 0.061743270902895844, 'n_estimators': 813, 'subsample': 0.5929870857331718, 'colsample_bytree': 0.5561024911967668, 'min_child_weight': 9, 'gamma': 0.6482362540039752}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:29:34,346] Trial 31 finished with value: 0.6822476190476191 and parameters: {'max_depth': 7, 'learning_rate': 0.0602317752589616, 'n_estimators': 786, 'subsample': 0.5874425547775104, 'colsample_bytree': 0.7863968427045533, 'min_child_weight': 9, 'gamma': 0.5428087012767511}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:29:40,920] Trial 35 finished with value: 0.682447619047619 and parameters: {'max_depth': 4, 'learning_rate': 0.06115708931460641, 'n_estimators': 800, 'subsample': 0.5950174956855059, 'colsample_bytree': 0.8304415201664512, 'min_child_weight': 9, 'gamma': 0.961700007192205}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:31:20,608] Trial 36 finished with value: 0.6827587301587301 and parameters: {'max_depth': 4, 'learning_rate': 0.05944510437149593, 'n_estimators': 805, 'subsample': 0.6084016449290967, 'colsample_bytree': 0.8175469026213663, 'min_child_weight': 9, 'gamma': 0.6753754366821014}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:31:30,696] Trial 39 finished with value: 0.6822396825396826 and parameters: {'max_depth': 5, 'learning_rate': 0.07382838327697848, 'n_estimators': 426, 'subsample': 0.6055366983654, 'colsample_bytree': 0.8641941285268188, 'min_child_weight': 6, 'gamma': 1.3238458743438293}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:32:09,501] Trial 40 finished with value: 0.6824809523809524 and parameters: {'max_depth': 4, 'learning_rate': 0.07384140731236044, 'n_estimators': 635, 'subsample': 0.6222653792667141, 'colsample_bytree': 0.8640128394098504, 'min_child_weight': 4, 'gamma': 1.2619849917551282}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:32:42,081] Trial 37 finished with value: 0.6830666666666667 and parameters: {'max_depth': 4, 'learning_rate': 0.07014362374357191, 'n_estimators': 829, 'subsample': 0.6238634578732183, 'colsample_bytree': 0.8372062568444187, 'min_child_weight': 9, 'gamma': 0.6564481399095825}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:33:43,193] Trial 38 finished with value: 0.6836 and parameters: {'max_depth': 5, 'learning_rate': 0.07381920716495145, 'n_estimators': 830, 'subsample': 0.6066617359105336, 'colsample_bytree': 0.8135059760053709, 'min_child_weight': 9, 'gamma': 0.5997302828847177}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:33:47,542] Trial 42 finished with value: 0.6829746031746031 and parameters: {'max_depth': 5, 'learning_rate': 0.07250517702640825, 'n_estimators': 689, 'subsample': 0.6177225399215295, 'colsample_bytree': 0.635006200821657, 'min_child_weight': 4, 'gamma': 1.24826353591034}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:34:21,462] Trial 41 finished with value: 0.6825285714285714 and parameters: {'max_depth': 6, 'learning_rate': 0.07467490125422169, 'n_estimators': 703, 'subsample': 0.6303920576078984, 'colsample_bytree': 0.8791679468066406, 'min_child_weight': 4, 'gamma': 1.4517608626313032}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:34:25,241] Trial 43 finished with value: 0.6829063492063492 and parameters: {'max_depth': 6, 'learning_rate': 0.07319498815222383, 'n_estimators': 667, 'subsample': 0.6341764687312743, 'colsample_bytree': 0.8688911056514037, 'min_child_weight': 4, 'gamma': 1.343959649568154}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:35:52,389] Trial 44 finished with value: 0.6830031746031746 and parameters: {'max_depth': 6, 'learning_rate': 0.07665433015733512, 'n_estimators': 649, 'subsample': 0.6448562966438829, 'colsample_bytree': 0.6352282839804007, 'min_child_weight': 4, 'gamma': 1.3592840950773677}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:36:24,054] Trial 46 finished with value: 0.6833539682539683 and parameters: {'max_depth': 6, 'learning_rate': 0.08447193888073481, 'n_estimators': 692, 'subsample': 0.8028308307748718, 'colsample_bytree': 0.6369846801691812, 'min_child_weight': 8, 'gamma': 2.6004344935823775}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:37:08,892] Trial 47 finished with value: 0.6833142857142857 and parameters: {'max_depth': 6, 'learning_rate': 0.08541975113964939, 'n_estimators': 704, 'subsample': 0.7937377443803082, 'colsample_bytree': 0.6361083472372212, 'min_child_weight': 8, 'gamma': 2.458716076557475}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:37:40,247] Trial 45 finished with value: 0.6829476190476191 and parameters: {'max_depth': 6, 'learning_rate': 0.08416526484341084, 'n_estimators': 889, 'subsample': 0.6461725528449328, 'colsample_bytree': 0.6219463579769107, 'min_child_weight': 8, 'gamma': 1.57096085725379}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:38:30,359] Trial 48 finished with value: 0.6835269841269842 and parameters: {'max_depth': 6, 'learning_rate': 0.08453007900087037, 'n_estimators': 700, 'subsample': 0.6746725949052368, 'colsample_bytree': 0.6671231034398997, 'min_child_weight': 8, 'gamma': 0.42561397609169027}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:39:43,660] Trial 49 finished with value: 0.6830142857142857 and parameters: {'max_depth': 6, 'learning_rate': 0.08283278959627825, 'n_estimators': 878, 'subsample': 0.6789541483284107, 'colsample_bytree': 0.7760044187482361, 'min_child_weight': 8, 'gamma': 2.5658789969384057}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:40:22,652] Trial 50 finished with value: 0.6827698412698412 and parameters: {'max_depth': 6, 'learning_rate': 0.0830775603484952, 'n_estimators': 885, 'subsample': 0.6681937830002282, 'colsample_bytree': 0.7591733860776788, 'min_child_weight': 8, 'gamma': 2.5852460367001697}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:40:30,394] Trial 51 finished with value: 0.6828650793650793 and parameters: {'max_depth': 6, 'learning_rate': 0.08237098670385701, 'n_estimators': 891, 'subsample': 0.7050198126315776, 'colsample_bytree': 0.9962163933423963, 'min_child_weight': 8, 'gamma': 2.5340903346584103}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:41:05,173] Trial 52 finished with value: 0.6836047619047619 and parameters: {'max_depth': 5, 'learning_rate': 0.08665633651056748, 'n_estimators': 881, 'subsample': 0.690081639566928, 'colsample_bytree': 0.9464873803099106, 'min_child_weight': 8, 'gamma': 2.5647617136745007}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:41:43,211] Trial 53 finished with value: 0.6834730158730158 and parameters: {'max_depth': 5, 'learning_rate': 0.09386633512890338, 'n_estimators': 887, 'subsample': 0.6707241954739752, 'colsample_bytree': 0.7801455731886983, 'min_child_weight': 8, 'gamma': 0.3472208019247106}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:41:48,511] Trial 56 finished with value: 0.6830507936507937 and parameters: {'max_depth': 5, 'learning_rate': 0.09377784807988088, 'n_estimators': 578, 'subsample': 0.6802542366039745, 'colsample_bytree': 0.6974701747877714, 'min_child_weight': 7, 'gamma': 3.6536927650369284}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:42:30,057] Trial 54 finished with value: 0.6833825396825397 and parameters: {'max_depth': 5, 'learning_rate': 0.09324611953900393, 'n_estimators': 889, 'subsample': 0.6844614677334255, 'colsample_bytree': 0.6726005297683024, 'min_child_weight': 7, 'gamma': 0.3759711922551396}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:42:54,924] Trial 55 finished with value: 0.683747619047619 and parameters: {'max_depth': 5, 'learning_rate': 0.09218342524838255, 'n_estimators': 867, 'subsample': 0.6742613110173094, 'colsample_bytree': 0.9526334958565668, 'min_child_weight': 5, 'gamma': 0.42008647417019424}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:43:18,152] Trial 57 finished with value: 0.6832619047619047 and parameters: {'max_depth': 5, 'learning_rate': 0.09184702210459651, 'n_estimators': 602, 'subsample': 0.6795049553363033, 'colsample_bytree': 0.9454953016768055, 'min_child_weight': 7, 'gamma': 3.5510235625113733}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:43:26,056] Trial 64 finished with value: 0.6704634920634922 and parameters: {'max_depth': 3, 'learning_rate': 0.08994722622586303, 'n_estimators': 114, 'subsample': 0.7086694187157031, 'colsample_bytree': 0.9303898584456838, 'min_child_weight': 5, 'gamma': 3.319747719677335}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:44:10,508] Trial 59 finished with value: 0.6833714285714285 and parameters: {'max_depth': 5, 'learning_rate': 0.09515992682970403, 'n_estimators': 597, 'subsample': 0.7385878216643184, 'colsample_bytree': 0.6860080514859485, 'min_child_weight': 7, 'gamma': 0.39130696376374263}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:45:01,095] Trial 61 finished with value: 0.6834634920634921 and parameters: {'max_depth': 5, 'learning_rate': 0.09163338739195698, 'n_estimators': 588, 'subsample': 0.7373826426603193, 'colsample_bytree': 0.6889981652723713, 'min_child_weight': 7, 'gamma': 3.571490054033131}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:45:36,437] Trial 58 finished with value: 0.6836206349206349 and parameters: {'max_depth': 5, 'learning_rate': 0.09072701107218166, 'n_estimators': 851, 'subsample': 0.7102677159230866, 'colsample_bytree': 0.6881363425728384, 'min_child_weight': 7, 'gamma': 0.3766575899378566}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:46:24,154] Trial 60 finished with value: 0.6836238095238094 and parameters: {'max_depth': 5, 'learning_rate': 0.09224133315826204, 'n_estimators': 858, 'subsample': 0.7205676155680871, 'colsample_bytree': 0.9469657643883513, 'min_child_weight': 7, 'gamma': 0.326779729208738}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:47:09,683] Trial 62 finished with value: 0.6833920634920634 and parameters: {'max_depth': 5, 'learning_rate': 0.09203890709539041, 'n_estimators': 865, 'subsample': 0.7338778719634735, 'colsample_bytree': 0.9503205457470948, 'min_child_weight': 7, 'gamma': 0.3799621999556949}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:47:18,655] Trial 63 finished with value: 0.6835015873015873 and parameters: {'max_depth': 5, 'learning_rate': 0.08961181840528387, 'n_estimators': 856, 'subsample': 0.7345954588263667, 'colsample_bytree': 0.9459808435905842, 'min_child_weight': 7, 'gamma': 3.3135793113739584}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:47:34,076] Trial 65 finished with value: 0.6830857142857144 and parameters: {'max_depth': 4, 'learning_rate': 0.0970017558795794, 'n_estimators': 850, 'subsample': 0.7422000381852724, 'colsample_bytree': 0.936695018510494, 'min_child_weight': 5, 'gamma': 3.0761384817291533}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:47:53,431] Trial 66 finished with value: 0.6838206349206348 and parameters: {'max_depth': 4, 'learning_rate': 0.09807691370069972, 'n_estimators': 863, 'subsample': 0.7447513640668504, 'colsample_bytree': 0.8986718241577344, 'min_child_weight': 6, 'gamma': 1.812325628892061}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:48:36,213] Trial 67 finished with value: 0.6835619047619048 and parameters: {'max_depth': 4, 'learning_rate': 0.09780192207656227, 'n_estimators': 850, 'subsample': 0.7173919768229527, 'colsample_bytree': 0.9000079381130343, 'min_child_weight': 6, 'gamma': 1.8777017849665119}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:49:31,737] Trial 68 finished with value: 0.6837444444444445 and parameters: {'max_depth': 4, 'learning_rate': 0.09839315869012275, 'n_estimators': 855, 'subsample': 0.7700867919563837, 'colsample_bytree': 0.9049727220171164, 'min_child_weight': 5, 'gamma': 0.2698733693242241}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:50:06,970] Trial 69 finished with value: 0.6835190476190476 and parameters: {'max_depth': 4, 'learning_rate': 0.09774774823897801, 'n_estimators': 851, 'subsample': 0.7780278812215772, 'colsample_bytree': 0.8938430137160873, 'min_child_weight': 6, 'gamma': 1.089927813305473}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:50:50,124] Trial 70 finished with value: 0.683747619047619 and parameters: {'max_depth': 4, 'learning_rate': 0.09755339027352602, 'n_estimators': 856, 'subsample': 0.7705520379076893, 'colsample_bytree': 0.9723211516552485, 'min_child_weight': 6, 'gamma': 2.8713428457510948}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:51:28,079] Trial 73 finished with value: 0.6830174603174604 and parameters: {'max_depth': 3, 'learning_rate': 0.08886731969116833, 'n_estimators': 910, 'subsample': 0.7690627083558004, 'colsample_bytree': 0.8963505449523743, 'min_child_weight': 6, 'gamma': 1.0470061334248173}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:51:52,330] Trial 74 finished with value: 0.6833730158730159 and parameters: {'max_depth': 3, 'learning_rate': 0.09970247479317856, 'n_estimators': 926, 'subsample': 0.7671983782478509, 'colsample_bytree': 0.9051062050737066, 'min_child_weight': 6, 'gamma': 1.8265710897933687}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:52:10,101] Trial 71 finished with value: 0.6834873015873016 and parameters: {'max_depth': 4, 'learning_rate': 0.09748026653335254, 'n_estimators': 930, 'subsample': 0.7838630915751051, 'colsample_bytree': 0.8992799807005832, 'min_child_weight': 6, 'gamma': 1.0582661092437493}. Best is trial 12 with value: 0.6838285714285715.
# [I 2025-12-11 03:52:15,251] Trial 72 finished with value: 0.6838634920634921 and parameters: {'max_depth': 4, 'learning_rate': 0.09803359000178208, 'n_estimators': 915, 'subsample': 0.7747934280759352, 'colsample_bytree': 0.9013055794800423, 'min_child_weight': 6, 'gamma': 1.0778273047422868}. Best is trial 72 with value: 0.6838634920634921.
# [I 2025-12-11 03:52:39,445] Trial 75 finished with value: 0.683152380952381 and parameters: {'max_depth': 3, 'learning_rate': 0.09997440781145947, 'n_estimators': 923, 'subsample': 0.7774753134343471, 'colsample_bytree': 0.9082213519987802, 'min_child_weight': 6, 'gamma': 1.0856803416432252}. Best is trial 72 with value: 0.6838634920634921.
# [I 2025-12-11 03:53:35,302] Trial 76 finished with value: 0.6832047619047618 and parameters: {'max_depth': 3, 'learning_rate': 0.09965508306421393, 'n_estimators': 917, 'subsample': 0.7649069698638403, 'colsample_bytree': 0.9736890422711755, 'min_child_weight': 6, 'gamma': 1.05063328032583}. Best is trial 72 with value: 0.6838634920634921.
# [I 2025-12-11 03:54:11,656] Trial 77 finished with value: 0.6829793650793651 and parameters: {'max_depth': 3, 'learning_rate': 0.08821205396351983, 'n_estimators': 926, 'subsample': 0.7663451810515157, 'colsample_bytree': 0.9775269695693719, 'min_child_weight': 5, 'gamma': 2.7536375717509327}. Best is trial 72 with value: 0.6838634920634921.
# [I 2025-12-11 03:54:57,652] Trial 78 finished with value: 0.6828857142857142 and parameters: {'max_depth': 3, 'learning_rate': 0.08757817503194333, 'n_estimators': 935, 'subsample': 0.7546034729244476, 'colsample_bytree': 0.9724234095205873, 'min_child_weight': 5, 'gamma': 2.806122924592721}. Best is trial 72 with value: 0.6838634920634921.
# [I 2025-12-11 03:55:23,041] Trial 81 finished with value: 0.6819095238095239 and parameters: {'max_depth': 3, 'learning_rate': 0.07941656730862767, 'n_estimators': 727, 'subsample': 0.8249261964226781, 'colsample_bytree': 0.9687107454871074, 'min_child_weight': 5, 'gamma': 2.8541233364346033}. Best is trial 72 with value: 0.6838634920634921.
# [I 2025-12-11 03:56:20,260] Trial 82 finished with value: 0.6829904761904763 and parameters: {'max_depth': 3, 'learning_rate': 0.08861587973252735, 'n_estimators': 961, 'subsample': 0.8205274165724337, 'colsample_bytree': 0.9689782259218821, 'min_child_weight': 5, 'gamma': 2.905755703360713}. Best is trial 72 with value: 0.6838634920634921.
# [I 2025-12-11 03:56:23,198] Trial 79 finished with value: 0.6836603174603174 and parameters: {'max_depth': 4, 'learning_rate': 0.09888400839732332, 'n_estimators': 931, 'subsample': 0.7588148307224103, 'colsample_bytree': 0.9766703993441769, 'min_child_weight': 5, 'gamma': 2.8897159272066073}. Best is trial 72 with value: 0.6838634920634921.
# [I 2025-12-11 03:56:27,868] Trial 80 finished with value: 0.6835111111111111 and parameters: {'max_depth': 4, 'learning_rate': 0.08721333913431968, 'n_estimators': 933, 'subsample': 0.8417605358412406, 'colsample_bytree': 0.9955002747784268, 'min_child_weight': 5, 'gamma': 2.846396512959935}. Best is trial 72 with value: 0.6838634920634921.
# [I 2025-12-11 03:56:34,654] Trial 83 finished with value: 0.6833809523809524 and parameters: {'max_depth': 4, 'learning_rate': 0.08777714242609758, 'n_estimators': 746, 'subsample': 0.8377471997215764, 'colsample_bytree': 0.9831656417474399, 'min_child_weight': 5, 'gamma': 2.7453551284570357}. Best is trial 72 with value: 0.6838634920634921.
# [I 2025-12-11 03:58:15,616] Trial 84 finished with value: 0.6833539682539682 and parameters: {'max_depth': 4, 'learning_rate': 0.07947116646824978, 'n_estimators': 959, 'subsample': 0.8400795487151447, 'colsample_bytree': 0.9852779587992806, 'min_child_weight': 5, 'gamma': 2.8343878524648938}. Best is trial 72 with value: 0.6838634920634921.
# [I 2025-12-11 03:58:48,442] Trial 86 finished with value: 0.6832079365079367 and parameters: {'max_depth': 4, 'learning_rate': 0.08016471504238543, 'n_estimators': 728, 'subsample': 0.8253774616235006, 'colsample_bytree': 0.9968701506198819, 'min_child_weight': 5, 'gamma': 2.3049763597612696}. Best is trial 72 with value: 0.6838634920634921.
# [I 2025-12-11 03:59:18,323] Trial 87 finished with value: 0.6836126984126984 and parameters: {'max_depth': 4, 'learning_rate': 0.09599105629236075, 'n_estimators': 742, 'subsample': 0.86119986571378, 'colsample_bytree': 0.9209130825311561, 'min_child_weight': 5, 'gamma': 0.7425019985154189}. Best is trial 72 with value: 0.6838634920634921.
# [I 2025-12-11 03:59:19,086] Trial 85 finished with value: 0.6839174603174603 and parameters: {'max_depth': 4, 'learning_rate': 0.09570305239161521, 'n_estimators': 968, 'subsample': 0.8238164396842754, 'colsample_bytree': 0.9917130298063864, 'min_child_weight': 5, 'gamma': 0.7881950362127934}. Best is trial 85 with value: 0.6839174603174603.
# [I 2025-12-11 04:00:33,331] Trial 88 finished with value: 0.683468253968254 and parameters: {'max_depth': 4, 'learning_rate': 0.0963766405666326, 'n_estimators': 787, 'subsample': 0.7004005307680913, 'colsample_bytree': 0.9199352557558848, 'min_child_weight': 6, 'gamma': 2.3756957778813073}. Best is trial 85 with value: 0.6839174603174603.
# [I 2025-12-11 04:00:40,330] Trial 90 finished with value: 0.6834904761904762 and parameters: {'max_depth': 4, 'learning_rate': 0.09602842692894795, 'n_estimators': 783, 'subsample': 0.7005312116623105, 'colsample_bytree': 0.9228953986983346, 'min_child_weight': 5, 'gamma': 0.1954059401690974}. Best is trial 85 with value: 0.6839174603174603.
# [I 2025-12-11 04:00:47,210] Trial 91 finished with value: 0.6837571428571428 and parameters: {'max_depth': 4, 'learning_rate': 0.09558575639143052, 'n_estimators': 785, 'subsample': 0.6975046742025794, 'colsample_bytree': 0.9174842778258417, 'min_child_weight': 6, 'gamma': 2.3570679686273857}. Best is trial 85 with value: 0.6839174603174603.
# [I 2025-12-11 04:01:52,150] Trial 89 finished with value: 0.6839349206349207 and parameters: {'max_depth': 4, 'learning_rate': 0.09551612184073192, 'n_estimators': 998, 'subsample': 0.8484757328293488, 'colsample_bytree': 0.9170257137056017, 'min_child_weight': 5, 'gamma': 0.1993428902956595}. Best is trial 89 with value: 0.6839349206349207.
# [I 2025-12-11 04:02:42,289] Trial 92 finished with value: 0.6837714285714286 and parameters: {'max_depth': 4, 'learning_rate': 0.09574865723909784, 'n_estimators': 796, 'subsample': 0.6980607786107487, 'colsample_bytree': 0.9152669839234117, 'min_child_weight': 6, 'gamma': 2.272670472797196}. Best is trial 89 with value: 0.6839349206349207.
# [I 2025-12-11 04:03:07,788] Trial 93 finished with value: 0.6837492063492064 and parameters: {'max_depth': 4, 'learning_rate': 0.09530865026458119, 'n_estimators': 786, 'subsample': 0.6971124168438491, 'colsample_bytree': 0.9175721967838277, 'min_child_weight': 6, 'gamma': 0.17893427181768354}. Best is trial 89 with value: 0.6839349206349207.
# [I 2025-12-11 04:03:27,838] Trial 94 finished with value: 0.6835587301587301 and parameters: {'max_depth': 4, 'learning_rate': 0.09445196768599282, 'n_estimators': 784, 'subsample': 0.7239987540138947, 'colsample_bytree': 0.9584437789103702, 'min_child_weight': 6, 'gamma': 0.24299962314582235}. Best is trial 89 with value: 0.6839349206349207.
# [I 2025-12-11 04:04:08,142] Trial 95 finished with value: 0.683915873015873 and parameters: {'max_depth': 4, 'learning_rate': 0.09467543093307842, 'n_estimators': 990, 'subsample': 0.8020170108041037, 'colsample_bytree': 0.9592864796218243, 'min_child_weight': 6, 'gamma': 0.8582252294728322}. Best is trial 89 with value: 0.6839349206349207.
# [I 2025-12-11 04:04:42,734] Trial 99 finished with value: 0.6832920634920635 and parameters: {'max_depth': 4, 'learning_rate': 0.09466822934635, 'n_estimators': 998, 'subsample': 0.8881101707214857, 'colsample_bytree': 0.9595949189831029, 'min_child_weight': 6, 'gamma': 2.9941265603522065}. Best is trial 89 with value: 0.6839349206349207.
# [I 2025-12-11 04:04:43,455] Trial 96 finished with value: 0.6838428571428571 and parameters: {'max_depth': 4, 'learning_rate': 0.09496608168252493, 'n_estimators': 988, 'subsample': 0.7964777387364972, 'colsample_bytree': 0.9543625054764333, 'min_child_weight': 6, 'gamma': 0.1584300624694306}. Best is trial 89 with value: 0.6839349206349207.
# [I 2025-12-11 04:04:45,195] Trial 97 finished with value: 0.6839539682539681 and parameters: {'max_depth': 4, 'learning_rate': 0.09454630279231208, 'n_estimators': 985, 'subsample': 0.8003961466087515, 'colsample_bytree': 0.8787176911560595, 'min_child_weight': 6, 'gamma': 0.8541521922204053}. Best is trial 97 with value: 0.6839539682539681.
# [I 2025-12-11 04:04:46,064] Trial 98 finished with value: 0.6841571428571428 and parameters: {'max_depth': 4, 'learning_rate': 0.09385536094847208, 'n_estimators': 987, 'subsample': 0.7907862214472847, 'colsample_bytree': 0.8485555107421026, 'min_child_weight': 6, 'gamma': 1.6665315109967525}. Best is trial 98 with value: 0.6841571428571428.
#
# Best parameters: {'max_depth': 4, 'learning_rate': 0.09385536094847208, 'n_estimators': 987, 'subsample': 0.7907862214472847, 'colsample_bytree': 0.8485555107421026, 'min_child_weight': 6, 'gamma': 1.6665315109967525}

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
to_scale = ['age', 'alcohol_consumption_per_week',
       'physical_activity_minutes_per_week', 'diet_score',
       'sleep_hours_per_day', 'screen_time_hours_per_day', 'bmi',
       'waist_to_hip_ratio', 'systolic_bp', 'diastolic_bp', 'heart_rate',
       'cholesterol_total', 'hdl_cholesterol', 'ldl_cholesterol',
       'triglycerides', 'family_history_diabetes', 'hypertension_history',
       'cardiovascular_history']
X[to_scale] = scaler.fit_transform(X[to_scale])

# %%
from sklearn.metrics import classification_report

xgb_model = XGBClassifier(**best_params)
xgb_model.fit(X, y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8485555107421026, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, feature_weights=None,
#               gamma=1.6665315109967525, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.09385536094847208,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=6, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=987, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
submission_data = pd.read_csv('test.csv')
ids = submission_data['id']
submission_data = submission_data.drop('id', axis=1)

# %%
submission_data = pd.concat(
    [submission_data.drop(one_hot_categories, axis=1), pd.get_dummies(submission_data[one_hot_categories], dtype=int)], 
axis=1)

# %%
submission_data = pd.concat(
        [
        submission_data.drop(ordinal_categories, axis=1), 
        pd.DataFrame(ordinal_encoder.fit_transform(submission_data[ordinal_categories]), columns=ordinal_categories)
    ], 
axis=1)

# %%
submission_data[to_scale] = scaler.transform(submission_data[to_scale])

# %%
preds = xgb_model.predict(submission_data)
preds = pd.DataFrame(preds, columns=['diagnosed_diabetes'])

# %%
submission_result = pd.concat([ids, preds], axis=1).set_index('id')

# %%
submission_result.to_csv('submission.csv')
