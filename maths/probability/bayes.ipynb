# %% [markdown]
# В первой и в третьей группах одинаковое число студентов, а во второй – в 1,5 раза меньше, чем в первой. \
# Количество отличников составляет 9% в первой, 4% во второй и 6% в третьей группе. \
# а) Найти вероятность того, что случайно вызванный студент – отличник. \
# б) Случайно вызванный студент оказался отличником. Найти вероятность того, что студент учится в третьей группе.

# %% [markdown]
# P(H1) = 3/8 \
# P(H2) = 2/8 \
# P(H3) = 3/8 \
# P(A|H1) = 0.09 \
# P(A|H2) = 0.04 \
# P(A|H3) = 0.06 \
# a) P(A) = P(A|H1)P(H1) + P(A|H2)P(H2) + P(A|H3)P(H3) = 3/8 * 0.09 + 2/8 * 0.04 + 3/8 * 0.06 = 0.06625 \
# b) P(H3|A) = P(A|H3)P(H3) / P(A) = (0.06 * 3/8) / 0.06625 = 0.334

# %% [markdown]
#  Есть 4 кубика. На трех из них окрашена белым половина граней, а на четвертом кубике всего одна грань из шести белая. Наудачу выбранный кубик подбрасывается семь раз. Найти вероятность того, что был выбран четвертый кубик, если при семи подбрасываниях белая грань выпала ровно один раз.
